# %% [markdown]
# # Credit Card - Anomaly Detect
# https://www.kaggle.com/mlg-ulb/creditcardfraud

# %% [markdown]
# Python 3.6.5
# numpy 1.18.3
# pandas 0.24.2
# matplotlib 3.2.1

# %%
import os
import tarfile
import urllib
import pandas as pd 
import numpy as np
import pathlib

# %%
# %matplotlib inline

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams

rcParams['figure.figsize']= 14, 8

# %%
GIT_ROOT = "https://raw.githubusercontent.com/maitreyee-github/AI-Learning/datasets/"
print(GIT_ROOT)
local_path= os.path.join("C:\\","Users","Maitreyee","Documents","git_data")
print(local_path)
GIT_URL = GIT_ROOT + "creditcard.csv"
print(GIT_URL)
#LOCAL_PATH = os.path.join("C:","Users","Maitreyee" , "data")
#LOCAL_PATH= "C:\\Users\Maitreyee\Documents\git_data"
#print(LOCAL_PATH)
#HOUSING_URL = DOWNLOAD_ROOT + "/housing.csv"
#print(HOUSING_URL)
# Out:
# https://raw.githubusercontent.com/maitreyee-github/AI-Learning/datasets/
# C:\/Users/Maitreyee/Documents/git_data
# https://raw.githubusercontent.com/maitreyee-github/AI-Learning/datasets/creditcard.csv

# %%
ROOT_VAR = "C:"
a=ROOT_VAR
print("root:", a)
input_file_path = os.path.join(a, "Users", "Maitreyee", "Documents", "git_data")
print("input file path: " + str(input_file_path))
input_file = os.path.join(input_file_path,"creditcard.csv")
print(input_file)
windows_data_path=str(input_file)
data_path=windows_data_path
print(data_path)
#housing_data = pd.read_csv(input_file)
#housing_data.head()
#print("input file : ",input_file)
#C:\Users\Maitreyee\Documents\git_data>
# Out:
# root: C:
# input file path: C:/Users/Maitreyee/Documents/git_data
# C:/Users/Maitreyee/Documents/git_data/creditcard.csv
# C:/Users/Maitreyee/Documents/git_data/creditcard.csv

# %%
data_path = "/Users/sinhacho/Documents/Books/ML_Ops_with_ML_Flow/Credit_Card_Anomaly_Detection/creditcard.csv"

# %%
print(data_path)
# Out:
# /Users/sinhacho/Documents/Books/ML_Ops_with_ML_Flow/Credit_Card_Anomaly_Detection/creditcard.csv

# %%
df = pd.read_csv(data_path)

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.051634 -1.206921 -1.085339   40.80      0
# 8 -0.384157  0.011747  0.142404   93.20      0
# 9  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.473120e-16  8.042109e-16  5.282512e-16  4.456271e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.426896e-15  1.701640e-15 -3.662252e-16 -1.217809e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
anomalies = df[df.Class == 1]
normal = df[df.Class == 0]

# %%
print(f"Anomalies: {anomalies.shape}")
print(f"Normal: {normal.shape}")
# Out:
# Anomalies: (492, 31)
# Normal: (284315, 31)

# %%
class_counts = pd.value_counts(df['Class'], sort = True)
class_counts.plot(kind = 'bar' , rot=0)
plt.title("Class Distribution")
plt.xticks(range(2), ["Normal", "Anomaly"])
plt.xlabel("Label")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %%
anomalies.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
def plot_histogram(df, bins, column, log_scale=False):
    
    bins = 100
    
    anomalies = df[df.Class == 1]
    normal = df[df.Class == 0]
    
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
    fig.suptitle(f'Counts of {column} by Class')
    
    ax1.hist(anomalies[column], bins = bins , color = "red")
    ax1.set_title('Anomaly')
    
    ax2.hist(normal[column], bins = bins, color = "green")
    ax2.set_title('Normal')
    
    plt.xlabel(f'{column}')
    plt.ylabel('Count')
    
    if log_scale:
        plt.yscale('log')
        plt.xlim((np.min(df[column]) , np.max(df[column])))
    plt.show()

# %%
def plot_scatter(df, x_col, y_col, sharey = False):
    
    anomalies = df[df.Class == 1]
    normal = df[df.Class == 0]
    
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, sharey = sharey)
    fig.suptitle(f'{y_col} over {x_col} by Class')
    
    ax1.scatter(anomalies[x_col], anomalies[y_col], color="red")
    ax1.set_title('Anomaly')
    
    ax2.scatter(normal[x_col], normal[y_col], color="green")
    ax2.set_title('Normal')
    
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.show()

# %%
plt.scatter(df.Amount, df.Class)
plt.title("Transaction Amounts by Class")
plt.ylabel("Class")
plt.yticks(range(2), ["Normal", "Anomaly"])
plt.xlabel("Transaction Amounts by ($)")
plt.show()

# %%
bins = 100
plot_histogram(df, bins, "Amount", log_scale=True)

# %%
plt.hist(anomalies.Amount, bins = bins, color="red")
plt.show()

# %%
plt.scatter(df.Time, df.Class)
plt.title("Transactiion over Time by Class")
plt.ylabel("Class")
plt.yticks(range(2), ["Normal", "Anomaly"])
plt.xlabel("Time (s)")
plt.show()

# %%
plot_scatter(df, "Time", "Amount")

# %%
plot_histogram(df, bins, "Time")

# %%
plot_histogram(df, bins, "V1")

# %%
plot_scatter(df, "Amount", "V1", sharey=True)

# %%
plot_scatter(df, "Time", "V1",  sharey=True)

# %%
for f in range(1, 29):
    print(f'V{f} Counts')
    plot_histogram(df, bins, f'V{f}')
# Out:
# V1 Counts
# V2 Counts
# V3 Counts
# V4 Counts
# V5 Counts
# V6 Counts
# V7 Counts
# V8 Counts
# V9 Counts
# V10 Counts
# V11 Counts
# V12 Counts
# V13 Counts
# V14 Counts
# V15 Counts
# V16 Counts
# V17 Counts
# V18 Counts
# V19 Counts
# V20 Counts
# V21 Counts
# V22 Counts
# V23 Counts
# V24 Counts
# V25 Counts
# V26 Counts
# V27 Counts
# V28 Counts

# %%
for f in range(1, 29):
    print(f'V{f} Vs Time')
    plot_scatter(df, "Time", f'V{f}', sharey=True)
# Out:
# V1 Vs Time
# V2 Vs Time
# V3 Vs Time
# V4 Vs Time
# V5 Vs Time
# V6 Vs Time
# V7 Vs Time
# V8 Vs Time
# V9 Vs Time
# V10 Vs Time
# V11 Vs Time
# V12 Vs Time
# V13 Vs Time
# V14 Vs Time
# V15 Vs Time
# V16 Vs Time
# V17 Vs Time
# V18 Vs Time
# V19 Vs Time
# V20 Vs Time
# V21 Vs Time
# V22 Vs Time
# V23 Vs Time
# V24 Vs Time
# V25 Vs Time
# V26 Vs Time
# V27 Vs Time
# V28 Vs Time

# %%
for f in range(1, 29):
    print(f'Amount VS V{f}')
    plot_scatter(df, f'V{f}', "Amount", sharey=True)
# Out:
# Amount VS V1
# Amount VS V2
# Amount VS V3
# Amount VS V4
# Amount VS V5
# Amount VS V6
# Amount VS V7
# Amount VS V8
# Amount VS V9
# Amount VS V10
# Amount VS V11
# Amount VS V12
# Amount VS V13
# Amount VS V14
# Amount VS V15
# Amount VS V16
# Amount VS V17
# Amount VS V18
# Amount VS V19
# Amount VS V20
# Amount VS V21
# Amount VS V22
# Amount VS V23
# Amount VS V24
# Amount VS V25
# Amount VS V26
# Amount VS V27
# Amount VS V28

# %%
import numpy as np
import pandas as pd
import matplotlib #
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn #

# %%
normal = df[df.Class == 0].sample(frac=0.5, random_state=2020).reset_index(drop=True)
anomaly = df[df.Class == 1]
